# %% [markdown]
# # median Second-Order-Majorant

# %% [markdown]
# ## (papier avec Valentin) Algorithms for regularized LRA with KL-divergence
#
# ```{hint}
# See also [](../Fast_algorithms_for_rLRA/mSOM.ipynb) for a deeper discussion of fast algorithms for nonnegative LRA with beta-divergences.
# ```
#
# [Est-ce que j'aurai parlé de KL et MU avant ? On peut partir du principe que oui ? Il faudra compléter ici sinon]
#
# [Je pourrai aussi regrouper les 2 articles dans une page algos pour beta-div... à voir c'est surement un peu hard ici niveau transition].
#
# Having considered the theory of rLRA independently of the loss function (it is only required to be scale-invariant in the HRSI framework), let us consider the practical problem of computing solutions to HRSI. Rather than considering a large class of problem ({cite}`cohenEfficientAlgorithmsRegularized2025` considered $\beta$-divergences and all $\ell_p$ regularizations), let us focus here on KL-divergence and mixtures of $\ell_1$ and $\ell_2$ regularizations for simplicity for NMF:
#
# $$
#     \argmin{X_1\geq 0,\; X_2\geq 0} D_{\text{KL}}(M, X_1X_2^T) + \mu \left( \|X_1\|_1 + \|X_2\|_2^2\right).
# $$ (eq:KL-NMF-l1-l2)
#
# As discussed in [TODO](), a class of algorithms for minimizing KL-divergence is the Multiplicative Updates (MUs). MUs are derived in a variety of ways, namely as a preconditionned gradient descent, as a majorization-minimization algorithm, or as a heuristic built from KKT conditions {cite}`gillisNonnegativeMatrixFactorization2020`. It is however not recognized by many that these formulations are not equivalent anymore when considering variants of the NMF problem and in particular $\ell^2_2$ penalties.
#
# Take the subproblem of estimating factor matrix $X_2$ with fixed matrix $X_1$. The preconditionned gradient formulation of MUs is given by
#
# $$
# X_2^{(k+1)} = X_2^{(k)} - \frac{1}{P} \nabla ,
# $$
#
# where $P$ is a matrix chosen to cancel out the additive part of the gradient update. In this case, choosing
#
# $$
#
#
# a word on $\ell_1$.
